# %%
# Abdul Qadir Boxwala
# 0801CS201003

# Q1. Read the ParisHousing.csv file in panda frames in your Jupyter
# Notebook or Google Colab Notebook. Print the columns of csv. Print the first 6 rows and last 5
# rows of your dataset.
#----------------------------------------------------Ans1
import pandas as pd

# %%
df=pd.read_csv('ParisHousing.csv')

# %%
df.head(6)
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0         75523              3        0        1      63      9373
# 1         80771             39        1        1      98     39381
# 2         55712             58        0        1      19     34457
# 3         32316             47        0        0       6     27939
# 4         70429             19        1        1      90     38045
# 5         39223             36        0        1      17     39489
#
#    cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 0              3              8  2005           0                  1
# 1              8              6  2015           1                  0
# 2              6              8  2021           0                  0
# 3             10              4  2012           0                  1
# 4              3              7  1990           1                  0
# 5              8              6  2012           0                  1
#
# ...

# %%
df.tail(5)
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# 9995              7              6  2009           0                  1
# 9996              9              4  1990           0                  1
# 9997             10             10  2005           1                  1
# 9998              1              3  2010           0                  1
# 9999              6             10  1994           1                  0
#
#       basement  attic  garage  hasStorageRoom  hasGuestRoom      price
# ...

# %%
# Q2. Delete all duplicate rows and update 7 th row of column 'floors' with 37 then Print it.
#----------------------------------------------------Ans2
df=df.drop_duplicates()

# %%
df.loc[7,'floors']=37
print(df['floors'][7])
# Out:
# 37

# %%
# Q3. Write a Pandas program to split the following dataframe into groups based on all columns and
# calculate GroupBy value counts on the dataframe.
#----------------------------------------------------Ans3
print(df.groupby(list(housing)).size().unstack(fill_value=0))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17648\1120248139.py in <module>
# ----> 1 print(df.groupby(list(housing)).size().unstack(fill_value=0))
#
# NameError: name 'housing' is not defined

# %%
# Q4. Add a column ‘Total’, which contains addition of columns- hasyard, hasPool, isNewBuilt,
# hasStromProtector, hasStorage, hasGuestRoom.
#-----------------------------------------------------Ans4
df['Total']=df['hasYard']+df[ 'hasPool']+df[ 'isNewBuilt']+df[ 'hasStormProtector']+df[ 'hasStorageRoom']+df[ 'hasGuestRoom']
print(df)
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
# Q5. Print the rows where
# price is greater than 2604486.6.
# squareMeters is greater than 5000 and hasStorage.
# squareMeters is greater than 79770 and does not hasStorageRoom but have Category as Luxury.
#-------------------------------------------------Ans5
df.loc[df.price>2604486.6]
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9991         96173             12        1        0      36     36812
# 9992         33545             55        0        1      79      8288
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
df.loc[(df.squareMeters>5000) & (df.hasStorageRoom>0)]
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 4            70429             19        1        1      90     38045
# 8            51522              3        0        0      61      9047
# 9            39686             42        0        0      15     71019
# ...            ...            ...      ...      ...     ...       ...
# 9984         31856             82        0        1      13     68107
# 9985         76480             98        0        1      37     40978
# 9992         33545             55        0        1      79      8288
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
df.loc[(df.squareMeters>5000) & (df.hasStorageRoom==0)]
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 3            32316             47        0        0       6     27939
# 5            39223             36        0        1      17     39489
# 6            58682             10        1        1      99      6450
# 7            86929            100        1        0      37     98155
# ...            ...            ...      ...      ...     ...       ...
# 9989         90996             81        1        1      80      1085
# 9990          5537             65        0        1      24      5808
# 9991         96173             12        1        0      36     36812
# 9994         21514              5        0        1      11     91373
# 9996         44403             29        1        1      12     34606
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
# Q6. Save this updated data in a new dataframe called as new_df and download it in your local
# machine in csv format, excel format, text format.
#-----------------------------------------------------Ans6
new_df=df
print(df)
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 0            75523              3        0        1      63      9373
# 1            80771             39        1        1      98     39381
# 2            55712             58        0        1      19     34457
# 3            32316             47        0        0       6     27939
# 4            70429             19        1        1      90     38045
# ...            ...            ...      ...      ...     ...       ...
# 9995          1726             89        0        1       5     73133
# 9996         44403             29        1        1      12     34606
# 9997         83841              3        0        0      69     80933
# 9998         59036             70        0        0      96     55856
# 9999          1440             84        0        0      49     18412
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
new_df.to_csv('file1.csv')
new_df.to_csv('file1.xls')
new_df.to_csv('file1.txt')

# %%
# Q7. Write a Pandas program to find out rows in the year '2021' or '2020' from the ParisHousing.csv
#---------------------------------------------Ans7
df.loc[(df.made==2021) | (df.made==2020)]
# Out:
#       squareMeters  numberOfRooms  hasYard  hasPool  floors  cityCode  \
# 2            55712             58        0        1      19     34457
# 9            39686             42        0        0      15     71019
# 23           34782             47        0        0      73     35331
# 31           85443             40        1        1      54       339
# 45           92696             49        1        0      38     74381
# ...            ...            ...      ...      ...     ...       ...
# 9820         17466             90        0        1      43     38624
# 9847         66041             18        1        0      16     58842
# 9855         91711             57        1        0      48     47861
# 9931         86383             86        1        1      23     57015
# 9981         37986             97        0        1      40     37191
#
#       cityPartRange  numPrevOwners  made  isNewBuilt  hasStormProtector  \
# ...

# %%
# Q8. Write a Pandas program to identify the column(s) of a given DataFrame which have at least one
# missing value
#-------------------------------------------------Ans8
print(df.isna().any())
# Out:
# squareMeters         False
# numberOfRooms        False
# hasYard              False
# hasPool              False
# floors               False
# cityCode             False
# cityPartRange        False
# numPrevOwners        False
# made                 False
# isNewBuilt           False
# hasStormProtector    False
# basement             False
# attic                False
# garage               False
# hasStorageRoom       False
# hasGuestRoom         False
# price                False
# Total                False
# dtype: bool

# %%
# Q9. Print the maximum, minimum, mean, standard deviation, count values of the dataset. Print the
# unique values of the column ‘garage’.
#------------------------------------------------Ans9
df.max()
# Out:
# squareMeters            99999.0
# numberOfRooms             100.0
# hasYard                     1.0
# hasPool                     1.0
# floors                    100.0
# cityCode                99953.0
# cityPartRange              10.0
# numPrevOwners              10.0
# made                     2021.0
# isNewBuilt                  1.0
# hasStormProtector           1.0
# basement                10000.0
# attic                   10000.0
# garage                   1000.0
# hasStorageRoom              1.0
# hasGuestRoom               10.0
# price                10006771.2
# Total                      15.0
# dtype: float64

# %%
df.min()
# Out:
# squareMeters            89.0
# numberOfRooms            1.0
# hasYard                  0.0
# hasPool                  0.0
# floors                   1.0
# cityCode                 3.0
# cityPartRange            1.0
# numPrevOwners            1.0
# made                  1990.0
# isNewBuilt               0.0
# hasStormProtector        0.0
# basement                 0.0
# attic                    1.0
# garage                 100.0
# hasStorageRoom           0.0
# hasGuestRoom             0.0
# price                10313.5
# Total                    0.0
# dtype: float64

# %%
df.std()
# Out:
# squareMeters         2.877438e+04
# numberOfRooms        2.881670e+01
# hasYard              4.999493e-01
# hasPool              5.000148e-01
# floors               2.888681e+01
# cityCode             2.900668e+04
# cityPartRange        2.872024e+00
# numPrevOwners        2.856667e+00
# made                 9.308090e+00
# isNewBuilt           5.000242e-01
# hasStormProtector    5.000250e-01
# basement             2.876730e+03
# attic                2.894332e+03
# garage               2.620502e+02
# hasStorageRoom       5.000160e-01
# hasGuestRoom         3.176410e+00
# price                2.877424e+06
# Total                3.378126e+00
# dtype: float64

# %%
df.count()
# Out:
# squareMeters         10000
# numberOfRooms        10000
# hasYard              10000
# hasPool              10000
# floors               10000
# cityCode             10000
# cityPartRange        10000
# numPrevOwners        10000
# made                 10000
# isNewBuilt           10000
# hasStormProtector    10000
# basement             10000
# attic                10000
# garage               10000
# hasStorageRoom       10000
# hasGuestRoom         10000
# price                10000
# Total                10000
# dtype: int64

# %%
df.garage.unique()
# Out:
# array([ 956,  128,  135,  359,  292,  757,  848,  654,  807,  591,  684,
#         716,  374,  582,  240,  384,  726,  354,  162,  572,  330,  892,
#         732,  822,  904,  670,  328,  295,  395,  558,  116,  695,  388,
#         982,  919,  698,  798,  422,  512,  237,  269,  918,  930,  957,
#         874,  817,  307,  864,  313,  227,  680,  223,  630,  939,  559,
#         552,  494,  927,  352,  811,  120,  828,  230,  641,  199,  979,
#         968,  226,  366,  677,  808,  774,  144,  755,  766,  860,  289,
#         493,  800,  738,  616,  866,  986,  408,  519,  753,  974,  794,
#         723,  132,  740,  648,  810,  625,  290,  929,  869,  710,  342,
#         126,  564,  139,  849,  836,  809,  812,  568,  853,  686,  734,
#         498,  775,  787,  417,  675,  905,  514,  544,  243,  735,  728,
#         480,  933,  204,  409,  531,  640,  463,  275,  482,  302,  345,
#         637,  502,  786,  197,  964,  846,  580,  586,  983,  239,  837,
# ...

# %%
# Q10. Write a Pandas program to add summation to a row of the given excel file.
#----------------------------------------------Ans10
sum_of_rows=pd.DataFrame(df[list(df)].sum()).T
sum_of_rows
# Out:
#    squareMeters  numberOfRooms  hasYard  hasPool    floors     cityCode  \
# 0   498701312.0       503584.0   5087.0   4968.0  502789.0  502254861.0
#
#    cityPartRange  numPrevOwners        made  isNewBuilt  hasStormProtector  \
# 0        55101.0        55217.0  20054885.0      4991.0             4999.0
#
#      basement       attic     garage  hasStorageRoom  hasGuestRoom  \
# 0  50331039.0  50280106.0  5531212.0          5030.0       49946.0
#
#           price    Total
# 0  4.993448e+10  75021.0
